# %%
import pandas as pd

# Gunakan path lengkap yang tadi ketemu di terminal
path_asli = "/home/haikal/Downloads/house-pricing-jakarta/data_rumah.xlsx"
df = pd.read_excel(path_asli)
print("Berhasil! Ini 5 data pertamanya:")
print(df.head())
# Out:
# Running cells with 'Python 3.10.19' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/usr/sbin/python3.10 -m pip install ipykernel -U --user --force-reinstall'

# %%
import pandas as pd

# Di Colab, file yang diupload langsung masuk ke folder root '/content/'
df = pd.read_excel('data_rumah.xlsx')
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_575/511009343.py in <cell line: 0>()
#       2
#       3 # Di Colab, file yang diupload langsung masuk ke folder root '/content/'
# ----> 4 df = pd.read_excel('data_rumah.xlsx')
#       5 print(df.head())
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# ...
